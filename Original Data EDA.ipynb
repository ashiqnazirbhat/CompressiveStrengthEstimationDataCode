# %% [markdown]
# # Import Original Data

# %%
import pandas as pd
df = pd.read_csv('data.csv')

# %%
df
# Out:
#      WBRatio  OPC  PPC  DAYS   CO2  STRENGTH
# 0       0.45  400    0     7  0.00     22.57
# 1       0.45  400    0     7  0.00     29.51
# 2       0.45  400    0     7  0.00     20.66
# 3       0.45  400    0     7  0.05     25.30
# 4       0.45  400    0     7  0.05     24.03
# ..       ...  ...  ...   ...   ...       ...
# 265     0.55    0  350    56  0.15     29.66
# 266     0.55    0  350    56  0.15     29.71
# 267     0.55    0  350    56  0.20     27.44
# 268     0.55    0  350    56  0.20     31.58
# 269     0.55    0  350    56  0.20     25.46
#
# [270 rows x 6 columns]

# %%
# prompt: Water Binder Ratio	OPC	PPC	DAYS	CO2	STRENGTH are the columns in dataframe generate explortery data analysis

import pandas as pd
import matplotlib.pyplot as plt


import seaborn as sns

df = pd.read_csv('Data.csv')
print(df.head())  # Display the first few rows of the DataFrame
df.tail()

# Data types and missing values
print(df.info())
print(df.describe())
# Out:
#    WBRatio  OPC  PPC  DAYS   CO2  STRENGTH
# 0     0.45  400    0     7  0.00     22.57
# 1     0.45  400    0     7  0.00     29.51
# 2     0.45  400    0     7  0.00     20.66
# 3     0.45  400    0     7  0.05     25.30
# 4     0.45  400    0     7  0.05     24.03
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   WBRatio   270 non-null    float64
#  1   OPC       270 non-null    int64
#  2   PPC       270 non-null    int64
#  3   DAYS      270 non-null    int64
#  4   CO2       270 non-null    float64
#  5   STRENGTH  270 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 12.8 KB
# None
#           WBRatio         OPC         PPC        DAYS         CO2    STRENGTH
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     0.450000  208.333333  208.333333   30.333333    0.100000   36.383000
# ...

# %%
# Check for missing values
print(df.isnull().sum())

# Visualizations
# Histograms
df.hist(figsize=(10, 8))
plt.show()
# Out:
# WBRatio     0
# OPC         0
# PPC         0
# DAYS        0
# CO2         0
# STRENGTH    0
# dtype: int64

# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Helvetica']
plt.rcParams.update({'font.size': 15})

# Define a professional style
plt.style.use('seaborn-muted')

# Calculate layout dimensions
num_columns = len(df.columns)
rows = (num_columns + 2) // 3  # Adjust for a grid of up to 3 columns per row

# Create the box plots
fig, axes = plt.subplots(nrows=rows, ncols=3, figsize=(12, rows * 4))
axes = axes.flatten()  # Flatten for easier indexing

for i, column in enumerate(df.columns):
    df.boxplot(column=column, ax=axes[i], notch=True, patch_artist=True)
    axes[i].set_title(column, fontsize=12)

# Hide unused axes
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

# Add a watermark in the center
plt.figtext(0.5, 0.5, 'Ashiq Nazir Bhat', ha='center', va='center', fontsize=12, alpha=0.2, color='gray', rotation=30)

# Save the plot as a professional-looking PDF with 1200 DPI
plt.savefig('Dataplots.pdf', format='pdf', dpi=1200)

plt.show()
# Out:
# C:\Users\Ashiq\AppData\Local\Temp\ipykernel_23820\2902991428.py:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-muted')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create a professional-looking heatmap with gridlines
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    cbar_kws={'shrink': 0.8},
    square=True,
    linewidths=0.5,  # Adds gridlines
    linecolor='gray'  # Sets the gridline color
)

# Add a watermark in the center
plt.figtext(0.5, 0.5, 'Ashiq Nazir Bhat', ha='center', va='center', fontsize=12, alpha=0.2, color='gray', rotation=30)

# Save the plot as a PDF with 1200 DPI
plt.tight_layout()
plt.savefig('correlationmatrix.pdf', format='pdf', dpi=1200)

# Show the plot
plt.show()
